# %%
from os import mkdir, getcwd
from selenium import webdriver
from tools_ import *
from DataManagement import *

import time

# %%
user_account = {
    "email": "automail.robort@yandex.com",
    "pass": "fGwk093oiVtdJPuc8z2wtFjGcvzSi6eonkvWTjZa8glIE6uYJdvLTJv9dJWJVDgMy68Bozma3kKGkWDw"
}

# %%
def init_folder(name):
    path = f'{getcwd()}/{name}'
    try:
        mkdir(path)
    finally:
        return path

temp = init_folder('temp_00')
users_folder = init_folder('storage')
users_images = init_folder('images')

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", { 
    "profile.default_content_setting_values.notifications": 1 
})

# %%
driver = webdriver.Chrome(chrome_options=options, executable_path='/home/shanenoi/Desktop/Selenium/WebDriver/chromedriver')
# driver = webdriver.Chrome('/home/shanenoi/Desktop/Selenium/WebDriver/chromedriver')
# Out:
# <ipython-input-5-502859f25875>:1: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options, executable_path='/home/shanenoi/Desktop/Selenium/WebDriver/chromedriver')

# %%
web_ctrl = WebControl(driver)

# %%
# Login
web_ctrl.driver.get('https://facebook.com')

mail_holder = web_ctrl.driver.find_element_by_id('email')
mail_holder.clear()
mail_holder.send_keys(user_account['email'])

pass_holder = web_ctrl.driver.find_element_by_id('pass')
pass_holder.clear()
pass_holder.send_keys(user_account['pass'])

web_ctrl.driver.find_element_by_id('u_0_b').click()

# %%
current_task = CurrentTask(f'{temp}/user')

# %%
sql = SQL
DB_ARCHITECTURE = [
    'main',
    {
        "friends": [
            sql.TYPE_TEXT
        ],
        "images": [
            sql.TYPE_TEXT
        ]
    }
]

# %%
class Pers(object):
    
    def __init__(self, web_control, user_id):
        self.user_db = DataBase(f'{users_folder}/{user_id}.db')
        self.user_id = user_id
        self.web_ctrl = web_control
    
    def get_user_name(self):
        return self.web_ctrl.driver.execute_script(
            CrawlingJs\
            .convert_jsScript(
                CrawlingJs\
                .crawling_by_js['user_name']
            )
        )
    
    def load_more(self):
        self.web_ctrl.driver.execute_script(
            CrawlingJs\
            .convert_jsScript(
                CrawlingJs\
                .crawling_by_js['scroll_to_the_end_of_page']
            )
        )
        
    def get_list_friends(self):
        self.web_ctrl.driver.get(
            CrawlingJs\
            .default_link['list_friends']\
            .format(self.user_id)
        )
        return map(
            Person.get_friend_name,
            self.web_ctrl.driver.execute_script(
                CrawlingJs\
                .convert_jsScript(
                    CrawlingJs\
                    .crawling_by_js['list_friends']
                )
            )
        )
    
    def get_list_images(self):
        self.web_ctrl.driver.get(
            CrawlingJs\
            .default_link['list_images']\
            .format(self.user_id)
        )
        return map(
            self.download_image,
            self.web_ctrl.driver.execute_script(
                CrawlingJs\
                .convert_jsScript(
                    CrawlingJs\
                    .crawling_by_js['list_images']
                )
            )
        )
    
    def download_image(self, url):
        values = Person.get_image_name_and_size(url)
        internal_path = f'{users_images}/{values[0]}'
        if not current_task.isdone(values[0]):
        with open(internal_path, 'wb') as imf:
            imf.write(self.web_ctrl.get_content(values[1]))
        return internal_path
    
    def create_userdb(self):
        if not current_task.isdone(self.user_id):
            self.user_db.create_table(
                name=DB_ARCHITECTURE[0],
                architecture=DB_ARCHITECTURE[1]
            )
            current_task.add(self.user_id)
        # because this function will return generator
        list(self.user_db.run())
            
    def save(self, n_friends=0, n_images=0):
        """
        [+] n_friends: the number of scrolling to the bottom of friends page
        [+] n_images: the number of scrolling to the bottom of images page
        """
        self.web_ctrl.driver.get(
            CrawlingJs\
            .default_link['list_friends']\
            .format(self.user_id)
        )
        current = self.web_ctrl.driver.execute_script(
                CrawlingJs\
                .convert_jsScript(
                    CrawlingJs\
                    .crawling_by_js['length_page']
                )
            )
        for i in range(n_friends):
            while (self.web_ctrl.driver.execute_script(
                    CrawlingJs\
                    .convert_jsScript(
                        CrawlingJs\
                        .crawling_by_js['length_page']
                    )
                ) == current):
                self.web_ctrl.driver.execute_script(
                    CrawlingJs\
                    .convert_jsScript(
                        CrawlingJs\
                        .crawling_by_js['scroll_to_the_end_of_page']
                    )
                )
        
        self.web_ctrl.driver.get(
            CrawlingJs\
            .default_link['list_images']\
            .format(self.user_id)
        )
        current = self.web_ctrl.driver.execute_script(
                CrawlingJs\
                .convert_jsScript(
                    CrawlingJs\
                    .crawling_by_js['length_page']
                )
            )
        for i in range(n_images):
            while (self.web_ctrl.driver.execute_script(
                    CrawlingJs\
                    .convert_jsScript(
                        CrawlingJs\
                        .crawling_by_js['length_page']
                    )
                ) == current):
                self.web_ctrl.driver.execute_script(
                    CrawlingJs\
                    .convert_jsScript(
                        CrawlingJs\
                        .crawling_by_js['scroll_to_the_end_of_page']
                    )
                )
                
        images = list(self.get_list_images())
        friends = list(self.get_list_friends())
        while images or friends:
            if images:
                self.user_db.insert_data(
                    table=DB_ARCHITECTURE[0],
                    specify_columns=['images'],
                    values=[images.pop(0)]
                )
            if friends:
                self.user_db.insert_data(
                    table=DB_ARCHITECTURE[0],
                    specify_columns=['friends'],
                    values=[friends.pop(0)]
                )
        list(self.user_db.run())

# %%
p = Pers(web_ctrl, 'tran.q.huy.71')
p.create_userdb()
# Out:
# ['CREATE TABLE main (friends TEXT, images TEXT)', '']

# %%
p.save()
# Out:
# 206x206__91133749_10218061434227245_2795824290069479424_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/91133749_10218061434227245_2795824290069479424_n.jpg?_nc_cat=107&_nc_sid=110474&_nc_oc=AQkyjk9o-DzR7Q70lPMr-Xn0ZYLpTZm9f5HLyJdJHOc8eMaa08BIphmzjRuXnDlmBOQ&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=ea7cebe4cade7ee95a18277d32cf39d6&oe=5EC2E47A
# 206x206__91142288_10218050011501684_1093292798599233536_o.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/91142288_10218050011501684_1093292798599233536_o.jpg?_nc_cat=101&_nc_sid=8024bb&_nc_oc=AQl9ekvKApC4FFuL9XUZbo9GSP5ipy-osLmWmu7UTNPtCy7m6Wy7uVKPuSMZPV_1yZg&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=f07e1b58a74bd64d38142c4ed6aef55b&oe=5EC41EC5
# 206x206__91404910_10218049209681639_4734492288904855552_o.jpg
# https://scontent.fsgn3-1.fna.fbcdn.net/v/t1.0-0/p206x206/91404910_10218049209681639_4734492288904855552_o.jpg?_nc_cat=104&_nc_sid=0be424&_nc_oc=AQlim5--tsp4-goJm83qOg_VEnjpcbMIh852BCTw77M9de6ed6GTpwxYujVOT8hj8TM&_nc_ht=scontent.fsgn3-1.fna&_nc_tp=6&oh=b89d59d534a2e75466bd8f6bd0e5d04c&oe=5EC2BEF7
# 206x206__90249273_10217972207236626_203072783968632832_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/90249273_10217972207236626_203072783968632832_n.jpg?_nc_cat=111&_nc_sid=0be424&_nc_oc=AQkvthgOLr20Hhvmzq3n9Hr20_WWHq77WpRf7rSt2YMgJNDI__djGe_uxZAfGdWQR_Y&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=d3aa5d3bed7a114fddffc54ea0ebd4fe&oe=5EC49B31
# 206x206__89914954_10217953524489569_8469675606496247808_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/89914954_10217953524489569_8469675606496247808_n.jpg?_nc_cat=101&_nc_sid=0be424&_nc_oc=AQlhNl37-oWJ3LanJe4yAXkZGI_P1BhE4hS5462zqKrPbrek3wASALvJv2PqFm5IBD0&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=1ea300dea86df0140ccaa4cc96e1f9de&oe=5EC26F00
# 206x206__89356873_10217878300489016_7212094562158772224_o.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/89356873_10217878300489016_7212094562158772224_o.jpg?_nc_cat=108&_nc_sid=110474&_nc_oc=AQmD4CQJcFOQLC4zxiOAZG2dtoXAIKNxj9qk74Eu7nZ8eOurDC5FRvWMrrXtkyO49AY&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=7798ea0b115b524e457fac761622ae3a&oe=5EC26A26
# 206x206__89451863_10217869566630675_6982507982999257088_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/89451863_10217869566630675_6982507982999257088_n.jpg?_nc_cat=106&_nc_sid=0be424&_nc_oc=AQkB7zCUQx1XrY9EsRX_henZ-3eovu1WLiSzZIBmTSTlMQNG02WZWPFdawQIYX5jInY&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=4aceaa3576da9bb27a67f05604253ae5&oe=5EC3F2DE
# 206x206__88169118_10217843323774620_6314283270141902848_o.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/88169118_10217843323774620_6314283270141902848_o.jpg?_nc_cat=106&_nc_sid=e007fa&_nc_oc=AQlfSM6RjyK_yZwIbQMhIuff7-6YCJoEMTEjShE-xpyOEPBOepfl3YEfrfLujQU1Na4&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=113dd1f3d9c0d59394ee0fadeb487993&oe=5EC3B1E9
# 206x206__89429031_10217843178050977_1354467904443121664_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/89429031_10217843178050977_1354467904443121664_n.jpg?_nc_cat=106&_nc_sid=110474&_nc_oc=AQlrCLTY63_T2Rnzww8_ktWLYgWgVcZTkbyGForNbVXz5XSzmFbqQzgGJJc65XPyvds&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=caed288108b4f1e1bbb909e9ce65cbe7&oe=5EC26934
# 206x206__88183290_10217793712414367_3633270954907402240_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/88183290_10217793712414367_3633270954907402240_n.jpg?_nc_cat=101&_nc_sid=0be424&_nc_oc=AQm1pvkYb2shfeGdyM0rCP9ldQb4Yb1fuAmZR6IRsdDnRzWtDMJX02-OuoMCZoyg024&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=5ae92ae410e6aaa9233331e928e03fb1&oe=5EC1BBC1
# 206x206__85077501_10217653547910342_953172879296430080_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/85077501_10217653547910342_953172879296430080_n.jpg?_nc_cat=103&_nc_sid=0be424&_nc_oc=AQnEffA0drNg8XIuavpV2xBhH-paEDwgVYts83ybNo-PODLc1OgL3Nz6HBTAlbtgnbU&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=66c912fc814ad6ca7d9094484fa4c1e1&oe=5EC1F595
# 206x206__84404430_10217636050952929_9208580568919310336_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/84404430_10217636050952929_9208580568919310336_n.jpg?_nc_cat=103&_nc_sid=0be424&_nc_oc=AQk6GVfGtPh9PeKlLw3oQL0Tk3E8m1FMNsYXE1GquMkxaKAxi74deiwn3R5DJ6HKcV4&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=c8617261846285a1aecd9cab35c26888&oe=5EC534B9
# 206x206__84817777_10217628229637401_5277360332459737088_n.jpg
# https://scontent.fsgn8-1.fna.fbcdn.net/v/t1.0-0/p206x206/84817777_10217628229637401_5277360332459737088_n.jpg?_nc_cat=102&_nc_sid=0be424&_nc_oc=AQkoMP6TFiJnxBO94Koj9Ac6j5RGRz5qBijKwYkdeQEVyz5o46nxlf7oHi_QpSYBVg4&_nc_ht=scontent.fsgn8-1.fna&_nc_tp=6&oh=d4d90a5cc583266a3b8823feb8104202&oe=5EC45B67
# 206x206__83498767_10217541259023190_4141483968207781888_n.jpg
# https://scontent.fsgn3-1.fna.fbcdn.net/v/t1.0-0/p206x206/83498767_10217541259023190_4141483968207781888_n.jpg?_nc_cat=104&_nc_sid=110474&_nc_oc=AQkrNIwKAeTZLX6FIcq7bfRX0aoCT0OTrdmMoNUtT5ySjLdO6fR5ZQrYsOHCVqDKvzw&_nc_ht=scontent.fsgn3-1.fna&_nc_tp=6&oh=586a59b0cdced56b2fafc3e5f162f2cb&oe=5EC307EB
# 206x206__84002459_10217466936325169_5294294490859700224_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/84002459_10217466936325169_5294294490859700224_n.jpg?_nc_cat=107&_nc_sid=0be424&_nc_oc=AQmnHj5FGwhpEgEq7vDPnDX2NLUjapk0ayg8u3b_NfUR2CfcE77BonFl-umDSbYh_5s&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=40f04c0549f9ae08cea72c0107cba1c5&oe=5EC2F759
# 206x206__83007231_10217466935645152_3656499113001746432_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/83007231_10217466935645152_3656499113001746432_n.jpg?_nc_cat=110&_nc_sid=0be424&_nc_oc=AQnCpsHenSOh_tC1zoQBmn8px8cYcafX6nkWoJp-cse42avcwMTLh4q3cKP-ulwCi58&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=48ddbc0f88a01d44bd0ca1a581f24caf&oe=5EC33E13
# 206x206__84183961_10217466935125139_4445550889507225600_n.jpg
# https://scontent-xsp1-2.xx.fbcdn.net/v/t1.0-0/p206x206/84183961_10217466935125139_4445550889507225600_n.jpg?_nc_cat=106&_nc_sid=0be424&_nc_oc=AQmcq4SG3S75HH7OsCXdWPoFOvFJBeoCh4VMpxeeCGDfuEFk705-UNwHeds8R5cwtIg&_nc_ht=scontent-xsp1-2.xx&_nc_tp=6&oh=138bc63055c6f28e19a29b0eb6e6b97f&oe=5EC46496
# 206x206__82693302_10217466934725129_1494173763128786944_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/82693302_10217466934725129_1494173763128786944_n.jpg?_nc_cat=109&_nc_sid=0be424&_nc_oc=AQkJChpAAReKzJ15NqtLiaxQWMdn9PKrWmEtHO0K4bjTlypwINp2BhcW4BI9Ep1_1uA&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=e49b6287ef19b1cfd06a90bd973e5212&oe=5EC14A3A
# 206x206__82605875_10217466934525124_339053952525926400_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/82605875_10217466934525124_339053952525926400_n.jpg?_nc_cat=108&_nc_sid=0be424&_nc_oc=AQmVD-PVn_F05T_5qG6jLQrUuvjySXCnomfBVKSS9dBLRSv4QgbNygIz7Vl28V11Ww4&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=4f7e9583dbc0ac4d7a90a762f2e396bc&oe=5EC52F28
# 206x206__82464715_10217363153850672_6721094149988155392_n.jpg
# https://scontent-xsp1-1.xx.fbcdn.net/v/t1.0-0/p206x206/82464715_10217363153850672_6721094149988155392_n.jpg?_nc_cat=108&_nc_sid=110474&_nc_oc=AQnmz07dyLrNyDDQJcSnRPa-Oyftw_CbeLNajFqZsxgmihSNCGNDzEf1ct2vtztV9_M&_nc_ht=scontent-xsp1-1.xx&_nc_tp=6&oh=a5ff245835c69984dac61038ec56e74b&oe=5EC1AFC5
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__91133749_10218061434227245_2795824290069479424_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['cuncu.nguyen']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__91142288_10218050011501684_1093292798599233536_o.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['profile.php?id=100005746382458']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__91404910_10218049209681639_4734492288904855552_o.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['huonglantran145']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__90249273_10217972207236626_203072783968632832_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['tranvantuan1110']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__89914954_10217953524489569_8469675606496247808_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['bienbien.it']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__89356873_10217878300489016_7212094562158772224_o.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['thanhtungyew']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__89451863_10217869566630675_6982507982999257088_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['khanhha190394']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__88169118_10217843323774620_6314283270141902848_o.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['cuongpv3000']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__89429031_10217843178050977_1354467904443121664_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['ngomanhtung92']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__88183290_10217793712414367_3633270954907402240_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['profile.php?id=100020095307655']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__85077501_10217653547910342_953172879296430080_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['songohan136']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__84404430_10217636050952929_9208580568919310336_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['athur.kiong']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__84817777_10217628229637401_5277360332459737088_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['tunght1990']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__83498767_10217541259023190_4141483968207781888_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['dinhhanh0808']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__84002459_10217466936325169_5294294490859700224_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['minh.mac.58']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__83007231_10217466935645152_3656499113001746432_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['nguyenthanhgiang3383']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__84183961_10217466935125139_4445550889507225600_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['mrduydx']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__82693302_10217466934725129_1494173763128786944_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['thangvnit1983']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__82605875_10217466934525124_339053952525926400_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['hien.dangvan.7']]
# ['INSERT INTO main (images) VALUES(?)', ['/home/shanenoi/Desktop/running/imags/206x206__82464715_10217363153850672_6721094149988155392_n.jpg']]
# ['INSERT INTO main (friends) VALUES(?)', ['Hahihihihihihihi']]
